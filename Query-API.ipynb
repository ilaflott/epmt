# %% [markdown]
# ## Import the data
#
# This workbook relies on importing data as follows:
#
# ```
# ./epmt -v submit ./sample/query/18431
# ./epmt -v submit ./sample/query/30385
# ```

# %%
# import the query api module
import epmt_query as eq
# Out:
# {'host': 'localhost', 'password': 'example', 'user': 'postgres', 'dbname': 'EPMT', 'provider': 'postgres'}

# %% [markdown]
# ## Basic Queries
#
# The API has a only a few queries: `get_jobs`, `get_procs` and `get_thread_metrics`
#
# Each of these operate at distinct levels: job, process and threads.

# %% [markdown]
# ### Job Query

# %%
# let's get jobs, let's try first without any filter
# we purposely set fmt='terse' to get just the job ids list
eq.get_jobs(fmt='terse')
# Out:
# [u'18431', u'30385', u'32046']

# %%
# above we got a list of job ids. That's not terribly useful.
# let's get a pandas dataframe of the actual process objects
eq.get_jobs(jobids = ['18431', '30385'], fmt='pandas')
# Out:
#   account  cpu_time    duration                        end env_changes_dict  \
# 0    None  27058683  45905753.0 2019-06-04 20:10:26.838998               {}
# 1    None     63523     97869.0 2019-06-04 20:14:24.878195               {}
#
#    exitcode info_dict  jobid jobname jobscriptname   ppr queue sessionid  \
# 0         0        []  18431   18431         18431  None  None      None
# 1         0        []  30385   30385         30385  None  None      None
#
#                        start submit tags                 updated_at    user
# 0 2019-06-04 20:09:40.933245   None   {} 2019-06-04 14:41:22.192377  tushar
# 1 2019-06-04 20:14:24.780326   None   {} 2019-06-04 14:44:53.964737  tushar

# %%
# if you prefer dealing with python lists and dictionaries,
# you can set fmt='dict' or just leave it out (as it's the default)
# below we get a list containing two dictionaries: one for each job
eq.get_jobs(jobids = ['18431', '30385'])
# Out:
# [{'account': None,
#   'cpu_time': 27058683,
#   'duration': 45905753.0,
#   'end': datetime.datetime(2019, 6, 4, 20, 10, 26, 838998),
#   'env_changes_dict': {},
#   'exitcode': 0,
#   'info_dict': [],
#   'jobid': u'18431',
#   'jobname': u'18431',
#   'jobscriptname': u'18431',
#   'ppr': None,
#   'queue': None,
#   'sessionid': None,
#   'start': datetime.datetime(2019, 6, 4, 20, 9, 40, 933245),
#   'submit': None,
#   'tags': {},
#   'updated_at': datetime.datetime(2019, 6, 4, 14, 41, 22, 192377),
#   'user': u'tushar'},
#  {'account': None,
#   'cpu_time': 63523,
#   'duration': 97869.0,
#   'end': datetime.datetime(2019, 6, 4, 20, 14, 24, 878195),
#   'env_changes_dict': {},
#   'exitcode': 0,
#   'info_dict': [],
#   'jobid': u'30385',
#   'jobname': u'30385',
#   'jobscriptname': u'30385',
#   'ppr': None,
#   'queue': None,
#   'sessionid': None,
#   'start': datetime.datetime(2019, 6, 4, 20, 14, 24, 780326),
#   'submit': None,
#   'tags': {},
#   'updated_at': datetime.datetime(2019, 6, 4, 14, 44, 53, 964737),
#   'user': u'tushar'}]

# %% [markdown]
# ### Process Query

# %%
# If you want to get the processes belonging to a job
# here each row in the pandas dataframe contains one job process
# again, you can use the 'terse' fmt option to get just the list of database ids of the processes
eq.get_procs(['18431'], fmt='pandas')
# Out:
#       PERF_COUNT_SW_CPU_CLOCK  \
# 0                     2595549
# 1                     1046856
# 2                  1208717443
# 3                      894723
# 4                      839139
# 5                      667088
# 6                      599278
# 7                      564519
# 8                      955785
# 9                     1018917
# 10                     773550
# 11                     835885
# 12                     693117
# 13                     835767
# 14                     728239
# 15                     716324
# 16                     898223
# 17                     800436
# 18                     845650
# 19                     710831
# 20                     607060
# 21                     892348
# 22                     846962
# 23                     837581
# 24                     533938
# 25                     755277
# 26                     738552
# 27                     771247
# 28                     735208
# 29                     799574
# ...                       ...
# 3586                   887436
# 3587                  1128500
# 3588                   824816
# 3589                  1079567
# 3590                   566816
# 3591                   776005
# 3592                   793473
# 3593                   723167
# 3594                   773467
# 3595                   513838
# 3596                   680899
# 3597                   531432
# 3598                   530911
# 3599                   708388
# 3600                   705447
# 3601                   598754
# 3602                   693593
# 3603                  1099140
# 3604                   709904
# 3605                   902987
# 3606                   891661
# 3607                  1014114
# 3608                   641269
# 3609                   772994
# 3610                   953127
# 3611                   720263
# 3612                   513815
# 3613                   588770
# 3614                   871670
# 3615                   745820
#
#                                                    args  \
# 0                                ./test-process-tree.sh
# 1                                ./test-process-tree.sh
# 2                                  /etc -exec stat {} ;
# 3                             /etc/ssl/certs/8b59b1ad.0
# 4      /etc/speech-dispatcher/modules/epos-generic.conf
# 5                             /etc/ssl/certs/455f1b52.0
# 6                           /etc/alternatives/LOCK.7.gz
# 7                                        /etc/glusterfs
# 8                    /etc/fonts/conf.d/40-nonlatin.conf
# 9                       /etc/brltty/Input/mm/common.kti
# 10                            /etc/ssl/certs/c7e2a638.0
# 11                       /etc/brltty/Input/pm/c_486.ktb
# 12               /etc/modprobe.d/blacklist-ath_pci.conf
# 13                         /etc/console-setup/remap.inc
# 14    /etc/dbus-1/system.d/com.ubuntu.SoftwareProper...
# 15              /etc/ssl/certs/OpenTrust_Root_CA_G1.pem
# 16                                 /etc/brltty/Input/at
# 17                         /etc/brltty/Input/bd/all.txt
# 18                            /etc/modprobe.d/dkms.conf
# 19                            /etc/ssl/certs/9f0f5fd6.0
# 20                    /etc/X11/app-defaults/Clock-color
# 21              /etc/apparmor.d/cache/usr.sbin.ippusbxd
# 22    /etc/apparmor.d/abstractions/ubuntu-browsers.d...
# 23                              /etc/apparmor.d/disable
# 24                            /etc/ssl/certs/40193066.0
# 25                       /etc/brltty/Text/num-alias.tti
# 26              /etc/ssl/certs/GeoTrust_Global_CA_2.pem
# 27            /etc/ssl/certs/LuxTrust_Global_Root_2.pem
# 28                            /etc/grub.d/20_memtest86+
# 29               /etc/ssl/certs/Certplus_Root_CA_G1.pem
# ...                                                 ...
# 3586  /etc/apparmor.d/abstractions/ubuntu-browsers.d...
# 3587             /etc/alternatives/CREATE_TABLE_AS.7.gz
# 3588                          /etc/X11/app-defaults/Xgc
# 3589                          /etc/init/hwclock.sh.conf
# 3590      /etc/xdg/autostart/indicator-keyboard.desktop
# 3591                           /etc/kernel/prerm.d/dkms
# 3592                                         /etc/groff
# 3593                             /etc/postfix/master.cf
# 3594  /etc/ssl/certs/Hellenic_Academic_and_Research_...
# 3595              /etc/fonts/conf.d/90-fonts-nanum.conf
# 3596      /etc/acpi/events/asus-keyboard-backlight-down
# 3597                         /etc/rc5.d/K01cups-browsed
# 3598                    /etc/rc1.d/K02nfs-kernel-server
# 3599                          /etc/ssl/certs/9c3323d4.0
# 3600                          /etc/ssl/certs/9d6523ce.0
# 3601                  /etc/brltty/Input/pm/el2d_80s.ktb
# 3602               /etc/dkms/template-dkms-mkdeb/debian
# 3603                                      /etc/crypttab
# 3604                  /etc/brltty/Input/pm/el_2d_80.ktb
# 3605                    /etc/brltty/Input/hm/qwerty.kti
# 3606                       /etc/alternatives/mailx.1.gz
# 3607  /etc/fonts/conf.avail/89-tlwg-waree-synthetic....
# 3608                         /etc/pam.d/common-password
# 3609                     /etc/brltty/Input/pm/el60c.ktb
# 3610  /etc/fonts/conf.avail/69-language-selector-zh-...
# 3611                          /etc/ssl/certs/cf701eeb.0
# 3612                        /etc/kernel/postinst.d/dkms
# 3613                          /etc/acpi/ibm-wireless.sh
# 3614                                /etc/rc6.d/K01mdadm
# 3615                            /etc/rcS.d/S02dns-clean
#
#       cancelled_write_bytes  delayacct_blkio_time    duration  \
# 0                         0                     0  45848263.0
# 1                         0                     0  35373741.0
# 2                         0                     0  35350474.0
# 3                         0                     0       901.0
# 4                         0                     0       845.0
# 5                         0                     0       672.0
# 6                         0                     0       604.0
# 7                         0                     0       569.0
# 8                         0                     0       963.0
# 9                         0                     0      1027.0
# 10                        0                     0       780.0
# 11                        0                     0       843.0
# 12                        0                     0       699.0
# 13                        0                     0       842.0
# 14                        0                     0       734.0
# 15                        0                     0       722.0
# 16                        0                     0       904.0
# 17                        0                     0       806.0
# 18                        0                     0       852.0
# 19                        0                     0       716.0
# 20                        0                     0       612.0
# 21                        0                     0       899.0
# 22                        0                     0       853.0
# 23                        0                     0       844.0
# 24                        0                     0       538.0
# 25                        0                     0       762.0
# 26                        0                     0       745.0
# 27                        0                     0       777.0
# 28                        0                     0       741.0
# 29                        0                     0       806.0
# ...                     ...                   ...         ...
# 3586                      0                     0       894.0
# 3587                      0                     0      1137.0
# 3588                      0                     0       831.0
# 3589                      0                     0      1088.0
# 3590                      0                     0       571.0
# 3591                      0                     0       782.0
# 3592                      0                     0       800.0
# 3593                      0                     0       729.0
# 3594                      0                     0       805.0
# 3595                      0                     0       517.0
# 3596                      0                     0       686.0
# 3597                      0                     0       536.0
# 3598                      0                     0       535.0
# 3599                      0                     0       713.0
# 3600                      0                     0       711.0
# 3601                      0                     0       603.0
# 3602                      0                     0       699.0
# 3603                      0                     0      1109.0
# 3604                      0                     0       716.0
# 3605                      0                     0       910.0
# 3606                      0                     0       898.0
# 3607                      0                     0      1022.0
# 3608                      0                     0       646.0
# 3609                      0                     0       779.0
# 3610                      0                     0       959.0
# 3611                      0                     0       725.0
# 3612                      0                     0       518.0
# 3613                      0                     0       595.0
# 3614                      0                     0       878.0
# 3615                      0                     0       751.0
#
#                             end  exclusive_cpu_time exename  exitcode  gen  \
# 0    2019-06-04 14:40:26.835416                8940    bash         0    0
# 3595  tushar         1966      1966         0      0            0
# 3596  tushar         6582      3291         0      0            0
# 3597  tushar         5182      2591         0      0            0
# 3598  tushar         4208      4208         0      0            0
# 3599  tushar         4039         0         0      0            0
# 3600  tushar         3332      3332         0      0            0
# 3601  tushar         7588      3794         0      0            0
# 3602  tushar         3724      3724         0      0            0
# 3603  tushar        11903     11903         0      0            0
# 3604  tushar         6456      3228         0      0            0
# 3605  tushar         9204         0         0      0            0
# 3606  tushar         9150      3050         0      0            0
# 3607  tushar         7761         0         0      0            0
# 3608  tushar         7180      3590         0      0            0
# 3609  tushar         5406      5406         0      0            0
# 3610  tushar         8764      5843         0      0            0
# 3611  tushar         4050      2025         0      0            0
# 3612  tushar         3913      3913         0      0            0
# 3613  tushar        11071      3690         0      0            0
# 3614  tushar         9837      3279         0      0            0
# 3615  tushar         6683         0         0      0            0
#
# [3616 rows x 49 columns]

# %%
# suppose you want to filter all processes by tags
eq.get_procs(tags = {'app':'w', 'phase': 'load'}, fmt='terse')
# Out:
# [3619, 3622]

# %%
# we could have got the process metadata and metric sums if we used fmt='pandas' or no fmt
# below, each row in the dataframe represents a single process
# You will observe that thread-level metrics (such as usertime, systemtime) are
# already aggregated and available as columns below
eq.get_procs(tags = {'app':'w', 'phase': 'load'}, fmt='pandas')
# Out:
#    PERF_COUNT_SW_CPU_CLOCK  args  cancelled_write_bytes  delayacct_blkio_time  \
# 0                   264920  load                      0                     0
# 1                  7906450                            0                     0
#
#    duration                        end  exclusive_cpu_time   exename  \
# 0    8583.0 2019-06-04 14:44:24.867268                9898      grep
# 1    7911.0 2019-06-04 14:44:24.867006               17448  w.procps
#
#    exitcode  gen  ... time_oncpu  time_waiting timeslices  \
# 0         0    0  ...    9898934             0          2
# 1         0    0  ...   17449098             0          1
#
#                   updated_at    user  user+system  usertime vol_ctxsw  wchar  \
# 0 2019-06-04 14:44:54.233242  tushar         9898      4949         1     71
# 1 2019-06-04 14:44:54.266024  tushar        17448     13086         0      0
#
#    write_bytes
# 0            0
# 1            0
#
# [2 rows x 49 columns]

# %% [markdown]
# ### Thread Query

# %%
# How about getting the threads metrics for these two processes?
eq.get_thread_metrics([3619, 3622])
# Out:
#      tid             start               end  usertime  systemtime  rssmax  \
# 0  27608  1559659464858685  1559659464867268      4949        4949    5172
# 0  27607  1559659464859095  1559659464867006     13086        4362    6472
#
#    minflt  majflt  inblock  outblock  ...  syscr  syscw  read_bytes  \
# 0     596       0        6         0  ...     72      1        3328
# 0     765       0        6         0  ...    696      0        3328
#
#    write_bytes  cancelled_write_bytes  time_oncpu  time_waiting  timeslices  \
# 0            0                      0     9898934             0           2
# 0            0                      0    17449098             0           1
#
#    rdtsc_duration  PERF_COUNT_SW_CPU_CLOCK
# 0        22253488                   264920
# 0        20512108                  7906450
#
# [2 rows x 29 columns]

# %% [markdown]
# ## Getting familiar with useful metrics and keys
#
# `get_jobs` and `get_procs` take a `fltr` and `order` option that can
# filter and sort the output based on schema columns.

# %%
# below we filter those processes of the job that exceed a certain
# wallclock time, and then sort them by the exclusive cpu time (user+system)
# fltr can be a lamdba function or a string
eq.get_procs('18431', fltr = lambda p: p.duration > 100000, order = 'desc(p.exclusive_cpu_time)', fmt='pandas')
# Out:
#    PERF_COUNT_SW_CPU_CLOCK                    args  cancelled_write_bytes  \
# 0               1208717443    /etc -exec stat {} ;                      0
# 1                440452151                    /usr                      0
# 2                   140609                      10                      0
# 3                  2595549  ./test-process-tree.sh                      0
# 4                  1046856  ./test-process-tree.sh                      0
#
#    delayacct_blkio_time    duration                        end  \
# 0                     0  35350474.0 2019-06-04 14:40:16.807963
# 1                     0    443123.0 2019-06-04 14:39:41.444421
# 2                     0  10000270.0 2019-06-04 14:40:26.834114
# 3                     0  45848263.0 2019-06-04 14:40:26.835416
# 4                     0  35373741.0 2019-06-04 14:40:16.821898
#
#    exclusive_cpu_time exename  exitcode  gen  ...  time_oncpu  time_waiting  \
# 0             1291036    find         1    0  ...  1291037628       3901716
# 1              453101    find         0    0  ...   453102131       2715435
# 2               10896   sleep         0    0  ...    10896060         15084
# 3                8940    bash         0    0  ...     8940761         96932
# 4                3947    bash         0    0  ...     3947356          4787
#
#   timeslices                 updated_at    user  user+system  usertime  \
# 0       3652 2019-06-04 14:41:24.858969  tushar      1291036    149926
# 1         50 2019-06-04 14:41:32.842824  tushar       453101    194754
# 2          2 2019-06-04 14:41:57.092744  tushar        10896      3632
# 3          6 2019-06-04 14:41:41.103896  tushar         8940      4470
# 4          3 2019-06-04 14:41:59.645593  tushar         3947      3947
#
#   vol_ctxsw     wchar  write_bytes
# 0      3614       246            0
# 1         0  13661217            0
# 2         1         0            0
# 3         5         0            0
# 4         2         0            0
#
# [5 rows x 49 columns]

# %% [markdown]
# ### Useful metrics and keys
#
# Below are some of the most useful keys in no particular order:
#
# #### Job Keys
#  - duration: this is the wallclock time in microseconds
#  - cpu_time: user+system time aggregated across all processes of the job
#  - start:    start time in microseconds since epoch
#  - end:      end time in microseconds since epoch
#  - jobid:    database id for job (unique)
#  - exitcode: return code from job
#  - tags:     dict of key/value pairs
#  - processes:list of processes belonging to job
#
#  #### Process Keys
#  - duration: this is the wallclock time in microseconds
#  - exclusive_cpu_time: user+system time for process (aggregated across it's threads)
#  - inclusive_cpu_time: user+system time for the process and *all its descendants*
#  - start:    start time in microseconds since epoch
#  - end:      end time in microseconds since epoch
#  - tags:     dict of key/value pairs
#  - threads_df: json serialized dataframe of process threads (ADVANCED)
#  - threads_sums: key/value pairs consisting of sums of thread metrics (ADVANCED)
#  - numtids:  number of threads
#  - exename
#  - args
#  - pid
#  - ppid
#  - id:       database ID for process
#  - exitcode
#  - parent
#  - children
#  - ancestors
#  - descendants
#
#  #### Thread Keys
#  - usertime
#  - systemtime
#  - user+system
#  - rssmax
#  - majflt
#  - read_bytes
#  - write_bytes

# %% [markdown]
# ## Case Study
#
# Let's walk through a contrived case study to get more familiar with the API.
# Along the way we will touch on some advanced topics such as the ORM. You will
# also see easy ways to navigate the process tree using the ORM.
#
# Consider the shell script below:
# ```
# $ cat sample/query/18431-job.sh
#
# #!/bin/bash
# export PAPIEX_TAGS="prog:dircrawl;phase:/usr"
# find /usr > /dev/null 2>&1
#
# export PAPIEX_TAGS="prog:find;phase:stat"
# (find /etc -exec stat {} \; ; ls -l /) > /dev/null 2>&1
# sleep 10
# ```

# %%
# ordinarily we would first find the job and then probe downwards
# You can use tags or fltr arguments to find the job
# As we did not include job tags in this script, let's just find the job using
# its job id
job = eq.get_jobs(jobids = ['18431'])[0]
job
# Out:
# {'account': None,
#  'cpu_time': 27058683,
#  'duration': 45905753.0,
#  'end': datetime.datetime(2019, 6, 4, 20, 10, 26, 838998),
#  'env_changes_dict': {},
#  'exitcode': 0,
#  'info_dict': [],
#  'jobid': u'18431',
#  'jobname': u'18431',
#  'jobscriptname': u'18431',
#  'ppr': None,
#  'queue': None,
#  'sessionid': None,
#  'start': datetime.datetime(2019, 6, 4, 20, 9, 40, 933245),
#  'submit': None,
#  'tags': {},
#  'updated_at': datetime.datetime(2019, 6, 4, 14, 41, 22, 192377),
#  'user': u'tushar'}

# %%
# now get the processes that are part of this job, let's sort them by the inclusive time
# we need to pass in the job id to restrict the query to a particular job
# the inclusive_cpu_time sums all the cpu times of the process and its dependents
# in this case you can see that after the top-level 'bash', the 'find' with the
# -exec stat shows up
procs = eq.get_procs(['18431'], order = 'desc(p.inclusive_cpu_time)', fmt='pandas')
procs
# Out:
#       PERF_COUNT_SW_CPU_CLOCK  \
# 0                     2595549
# 1                     1046856
# 2                  1208717443
# 3                   440452151
# 4                     1242723
# 5                     1001789
# 6                      963668
# 7                      998211
# 8                      864990
# 9                      982789
# 10                     875315
# 11                     756696
# 12                     826247
# 13                    1123352
# 14                     634020
# 15                    1208790
# 16                     636610
# 17                    1113335
# 18                    1090469
# 19                     494414
# 20                    1099297
# 21                     928749
# 22                     531981
# 23                    1111892
# 24                     959349
# 25                     499413
# 26                    1007301
# 27                     958067
# 28                     937106
# 29                    1128937
# ...                       ...
# 3586                   517170
# 3587                   541184
# 3588                   493582
# 3589                   496941
# 3590                   489457
# 3591                   490521
# 3592                   523882
# 3593                   507982
# 3594                   509540
# 3595                   500492
# 3596                   482926
# 3597                   504704
# 3598                   492309
# 3599                   482133
# 3600                   491744
# 3601                   507550
# 3602                   490812
# 3603                   492010
# 3604                   487301
# 3605                   491266
# 3606                   491556
# 3607                   485746
# 3608                   492999
# 3609                   513838
# 3610                   484604
# 3611                   500051
# 3612                   491068
# 3613                   505530
# 3614                   493708
# 3615                   483318
#
#                                                    args  \
# 0                                ./test-process-tree.sh
# 1                                ./test-process-tree.sh
# 2                                  /etc -exec stat {} ;
# 3                                                  /usr
# 4                                /etc/sane.d/artec.conf
# 5            /etc/ld.so.conf.d/x86_64-linux-gnu_GL.conf
# 6                    /etc/apparmor.d/abstractions/dconf
# 7                         /etc/alternatives/LISTEN.7.gz
# 8                            /etc/ppp/ip-down.d/postfix
# 9                             /etc/ssl/certs/e536d871.0
# 10                         /etc/alternatives/ex.ru.1.gz
# 11                                    /etc/default/dbus
# 12                 /etc/systemd/system/libvirtd.service
# 13                        /etc/alternatives/VACUUM.7.gz
# 14                             /etc/systemd/logind.conf
# 15                              /etc/lightdm/users.conf
# 16    /etc/fonts/conf.d/20-unhint-small-dejavu-lgc-s...
# 17    /etc/xdg/autostart/gnome-user-share-obexpush.d...
# 18                                      /etc/magic.mime
# 19                      /etc/alternatives/builtins.7.gz
# 20    /etc/systemd/system/cloud-final.service.wants/...
# 21                          /etc/brltty/Input/bm/pv.ktb
# 22                             /etc/emacs/site-start.el
# 23                     /etc/alternatives/DROP_USER.7.gz
# 24                              /etc/sane.d/sm3840.conf
# 25              /etc/cron.weekly/update-notifier-common
# 26                                 /etc/brltty/Input/hw
# 27    /etc/systemd/system/sockets.target.wants/dm-ev...
# 28                                /etc/alternatives/f77
# 29                                     /etc/sysctl.conf
# ...                                                 ...
# 3586              /etc/ssl/certs/Swisscom_Root_CA_2.pem
# 3587              /etc/zfs/zed.d/scrub.finish-notify.sh
# 3588                          /etc/X11/app-defaults/Xfd
# 3589       /etc/libvirt/nwfilter/no-arp-ip-spoofing.xml
# 3590                  /etc/ssl/certs/DST_Root_CA_X3.pem
# 3591          /etc/alternatives/ALTER_LARGE_OBJECT.7.gz
# 3592                                /etc/rc5.d/S01uuidd
# 3593                                        /etc/group-
# 3594                            /etc/init/apparmor.conf
# 3595                          /etc/ssl/certs/87753b0d.0
# 3596                                         /etc/rc3.d
# 3597                        /etc/brltty/Input/bm/sv.ktb
# 3598  /etc/ssl/certs/GeoTrust_Primary_Certification_...
# 3599                             /etc/alternatives/nawk
# 3600                 /etc/initramfs-tools/scripts/panic
# 3601                  /etc/ufw/applications.d/syncthing
# 3602                          /etc/ssl/certs/c9f83a1c.0
# 3603  /etc/fonts/conf.avail/20-unhint-small-dejavu-l...
# 3604  /etc/apparmor.d/libvirt/libvirt-6bbc1834-d5ce-...
# 3605                 /etc/alternatives/DROP_SCHEMA.7.gz
# 3606                        /etc/ssl/certs/Certigna.pem
# 3607                          /etc/ssl/certs/17b51fe6.0
# 3608                          /etc/ssl/certs/b7db1890.0
# 3609              /etc/fonts/conf.d/90-fonts-nanum.conf
# 3610               /etc/libvirt/nwfilter/allow-dhcp.xml
# 3611                   /etc/libvirt/storage/default.xml
# 3612                          /etc/ssl/certs/91739615.0
# 3613         /etc/ssl/certs/GlobalSign_Root_CA_-_R2.pem
# 3614                          /etc/ssl/certs/f387163d.0
# 3615                                     /etc/sudoers.d
#
#       cancelled_write_bytes  delayacct_blkio_time    duration  \
# 0                         0                     0  45848263.0
# 1                         0                     0  35373741.0
# 2                         0                     0  35350474.0
# 3                         0                     0    443123.0
# 4                         0                     0      1252.0
# 5                         0                     0      1009.0
# 6                         0                     0       970.0
# 7                         0                     0      1005.0
# 8                         0                     0       872.0
# 9                         0                     0       990.0
# 10                        0                     0       883.0
# 11                        0                     0       763.0
# 12                        0                     0       833.0
# 13                        0                     0      1132.0
# 14                        0                     0       640.0
# 15                        0                     0      1218.0
# 16                        0                     0       644.0
# 17                        0                     0      1123.0
# 18                        0                     0      1097.0
# 19                        0                     0       498.0
# 20                        0                     0      1106.0
# 7     tushar        13608         0         0         0            0
# 8     tushar        13426         0         0         0            0
# 9     tushar        13410      6705         0         0            0
# 10    tushar        13339         0         0         0            0
# 11    tushar        13248      6624         0         0            0
# 12    tushar        13233      3308         0         0            0
# 13    tushar        13073      9805         0         0            0
# 14    tushar        13048      3262         0         0            0
# 15    tushar        12958      3239         0         0            0
# 16    tushar        12957      3239         0         0            0
# 17    tushar        12928      9696         0         0            0
# 18    tushar        12898         0         0         0            0
# 19    tushar        12822         0         0         0            0
# 20    tushar        12798      3199         0         0            0
# 21    tushar        12778      6389         0         0            0
# 22    tushar        12778      6389         0         0            0
# 23    tushar        12718         0         0         0            0
# 24    tushar        12717         0         0         0            0
# 25    tushar        12705      3176         0         0            0
# 26    tushar        12658      9494         0         0            0
# 27    tushar        12649         0         0         0            0
# 28    tushar        12642      6321         0         0            0
# 29    tushar        12640      3160         0         0            0
# ...      ...          ...       ...       ...       ...          ...
# 3586  tushar         2322         0         0         0            0
# 3587  tushar         2322         0         0         0            0
# 3588  tushar         2293         0         0         0            0
# 3589  tushar         2292         0         0         0            0
# 3590  tushar         2268         0         0         0            0
# 3591  tushar         2245         0         0         0            0
# 3592  tushar         2231         0         0         0            0
# 3593  tushar         2196         0         0         0            0
# 3594  tushar         2194         0         0         0            0
# 3595  tushar         2174         0         0         0            0
# 3596  tushar         2131         0         0         0            0
# 3597  tushar         2111         0         0         0            0
# 3598  tushar         2102         0         0         0            0
# 3599  tushar         2092         0         0         0            0
# 3600  tushar         2087         0         0         0            0
# 3601  tushar         2079         0         0         0            0
# 3602  tushar         2076         0         0         0            0
# 3603  tushar         2058         0         0         0            0
# 3604  tushar         2040         0         0         0            0
# 3605  tushar         2027         0         0         0            0
# 3606  tushar         2024         0         0         0            0
# 3607  tushar         1996      1996         0         0            0
# 3608  tushar         1976         0         0         0            0
# 3609  tushar         1966      1966         0         0            0
# 3610  tushar         1951         0         0         0            0
# 3611  tushar         1869      1869         0         0            0
# 3612  tushar         1862         0         0         0            0
# 3613  tushar         1857         0         0         0            0
# 3614  tushar         1829         0         0         0            0
# 3615  tushar         1767         0         0         0            0
#
# [3616 rows x 49 columns]

# %%
# now let's try and see if one process was responsible for spawning too many processes
eq.get_procs(['18431'], fltr = 'count(p.children) > 100')
# Out:
# [{u'PERF_COUNT_SW_CPU_CLOCK': 1208717443,
#   'args': u'/etc -exec stat {} ;',
#   u'cancelled_write_bytes': 0,
#   u'delayacct_blkio_time': 0,
#   'duration': 35350474.0,
#   'end': datetime.datetime(2019, 6, 4, 14, 40, 16, 807963),
#   'exclusive_cpu_time': 1291036,
#   'exename': u'find',
#   'exitcode': 1,
#   'gen': 0,
#   'group': None,
#   u'guest_time': 0,
#   'host': u'earth',
#   'id': 3,
#   u'inblock': 6,
#   'inclusive_cpu_time': 26570768,
#   u'invol_ctxsw': 37,
#   'job': u'18431',
#   u'majflt': 0,
#   u'minflt': 56865,
#   'numtids': 1,
#   u'outblock': 0,
#   'parent': 2,
#   'path': u'/usr/bin/find',
#   'pgid': 19161,
#   'pid': 19166,
#   'ppid': 19165,
#   u'processor': 0,
#   u'rchar': 43842,
#   u'rdtsc_duration': 91702043696,
#   u'read_bytes': 3328,
#   u'rssmax': 6008,
#   'sid': 18431,
#   'start': datetime.datetime(2019, 6, 4, 14, 39, 41, 457489),
#   u'starttime': 324648960000,
#   u'syscr': 76,
#   u'syscw': 20,
#   u'systemtime': 1141110,
#   'tags': {u'phase': u'stat', u'prog': u'find'},
#   u'time_oncpu': 1291037628,
#   u'time_waiting': 3901716,
#   u'timeslices': 3652,
#   'updated_at': datetime.datetime(2019, 6, 4, 14, 41, 24, 858969),
#   'user': u'tushar',
#   u'user+system': 1291036,
#   u'usertime': 149926,
#   u'vol_ctxsw': 3614,
#   u'wchar': 246,
#   u'write_bytes': 0}]

# %%
# now let's walk through the process tree. To make this easy, we use the 'orm' format
# let's sort the processes by exclusive cpu time
# You will get a sorted list of ORM objects, let's see the top 10
procs = eq.get_procs(['18431'], order = 'desc(p.exclusive_cpu_time)', fmt='orm')[:10]
procs
# Out:
# [Process[3],
#  Process[929],
#  Process[654],
#  Process[1392],
#  Process[2021],
#  Process[1032],
#  Process[761],
#  Process[2575],
#  Process[786],
#  Process[2341]]

# %%
# lets pick up the first
p = procs[0]
p
# Out:
# Process[3]

# %%
p.exename
# Out:
# u'find'

# %%
p.exename, p.args, p.duration, len(p.children), p.numtids
# Out:
# (u'find', u'/etc -exec stat {} ;', 35350474.0, 3610, 1)

# %%
parent = p.parent
parent
# Out:
# Process[2]

# %%
parent.exename, parent.args, parent.pid, len(parent.children), len(parent.descendants)
# Out:
# (u'bash', u'./test-process-tree.sh', 19165, 2, 3612)

# %%
# let's see p's thread sums
p.threads_sums
# Out:
# {u'PERF_COUNT_SW_CPU_CLOCK': 1208717443,
#  u'cancelled_write_bytes': 0,
#  u'delayacct_blkio_time': 0,
#  u'guest_time': 0,
#  u'inblock': 6,
#  u'invol_ctxsw': 37,
#  u'majflt': 0,
#  u'minflt': 56865,
#  u'outblock': 0,
#  u'processor': 0,
#  u'rchar': 43842,
#  u'rdtsc_duration': 91702043696,
#  u'read_bytes': 3328,
#  u'rssmax': 6008,
#  u'starttime': 324648960000,
#  u'syscr': 76,
#  u'syscw': 20,
#  u'systemtime': 1141110,
#  u'time_oncpu': 1291037628,
#  u'time_waiting': 3901716,
#  u'timeslices': 3652,
#  u'user+system': 1291036,
#  u'usertime': 149926,
#  u'vol_ctxsw': 3614,
#  u'wchar': 246,
#  u'write_bytes': 0}

# %%
# let's get the thread dataframes for p
eq.get_thread_metrics(p)
# Out:
#      tid             start               end  usertime  systemtime  rssmax  \
# 0  19166  1559659181457489  1559659216807963    149926     1141110    6008
#
#    minflt  majflt  inblock  outblock  ...  syscr  syscw  read_bytes  \
# 0   56865       0        6         0  ...     76     20        3328
#
#    write_bytes  cancelled_write_bytes  time_oncpu  time_waiting  timeslices  \
# 0            0                      0  1291037628       3901716        3652
#
#    rdtsc_duration  PERF_COUNT_SW_CPU_CLOCK
# 0     91702043696               1208717443
#
# [1 rows x 29 columns]
